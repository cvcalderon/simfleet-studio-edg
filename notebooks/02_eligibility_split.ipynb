# %% [markdown]
# # R2 — Eligibility + Household Split
# Inspection notebook only. Core implementation lives in `src/simfleet_edg`.

# %%
from pathlib import Path

import pandas as pd

run = Path('../artifacts/runs/R2_eligibility_split_v1')
pd.read_csv(run / 'r2_validation.csv')
