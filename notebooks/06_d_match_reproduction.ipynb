# %% [markdown]
# # R6 — D_MATCH_FULLDAY_V1 reproduction
# Inspection notebook only. Core logic lives in `simfleet_edg.common.demand_match` and the official runner in `simfleet_edg.repro.r6_d_match`.

# %%
from pathlib import Path
import pandas as pd

run_dir = Path('../artifacts/runs/R6_d_match_v1')
pd.read_csv(run_dir / 'r6_summary.csv')

# %%
pd.read_csv(run_dir / 'match_tier_summary.csv')

# %%
pd.read_csv(run_dir / 'simfleet_edg_F2_1_validation_v1.csv')

# %%
pd.read_csv(run_dir / 'reproduction_witnesses.csv')
