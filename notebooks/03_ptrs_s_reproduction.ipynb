# %% [markdown]
# # R3 — P_TRS_EXP_V1 S-scale reproduction
#
# Thin inspection notebook. The authoritative implementation is `simfleet_edg.repro.r3_ptrs_s`; this notebook does not reimplement generation logic.

# %%
from pathlib import Path

import pandas as pd

run = Path('../artifacts/runs/R3_ptrs_s_v1')
pd.read_csv(run / 'run_validation.csv')

# %%
pd.read_csv(run / 'r3_summary.csv')
