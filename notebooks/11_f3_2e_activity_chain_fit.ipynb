# %% [markdown]
# # F3.2e — DG_ACTIVITY_CHAIN TRAIN-only fit
#
# Use only after overlay verification and implementation commit/push. CAL/TEST remain unopened.

# %%
from pathlib import Path

ROOT = Path.cwd()
CONFIG = ROOT / 'configs/f3/f3_2e_activity_chain_fit_v1.yaml'
OUT = ROOT / 'artifacts/runs/F3_2e_activity_chain_fit_v1'
assert CONFIG.exists()
assert not OUT.exists(), f'Official output already exists: {OUT}'
print('Ready for official TRAIN-only execution after commit verification.')

# %%
# Execute from a clean synchronized main only:
# !python -m simfleet_edg.repro.f3_2e_fit_activity_chain --config configs/f3/f3_2e_activity_chain_fit_v1.yaml --out artifacts/runs/F3_2e_activity_chain_fit_v1
