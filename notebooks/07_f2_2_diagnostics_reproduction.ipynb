# %% [markdown]
# # R7 — F2.2 diagnostic reproduction
# Thin orchestration notebook. The authoritative implementation is the Python module.

# %%
from pathlib import Path
ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
ROOT

# %%
# !python {ROOT / 'scripts' / 'verify_r7_prep.py'}

# %% [markdown]
# Official execution is performed from the shell after commit/push; do not run the 100k diagnostic job from this notebook as the authoritative execution.
