# %% [markdown]
# # R4 — P_TRS_EXP_V1 M-scale reproduction
# Scientific interface only. Core execution lives in `simfleet_edg.repro.r4_ptrs_m`.

# %%
from pathlib import Path

import yaml

cfg = yaml.safe_load(Path('../configs/reproduction/r4_ptrs_m.yaml').read_text())
cfg['population']

# %% [markdown]
# Official execution must be performed from the repository root after the implementation commit is clean and synchronized. Do not execute from this notebook as the authoritative run.
