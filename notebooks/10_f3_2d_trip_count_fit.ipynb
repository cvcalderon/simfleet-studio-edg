# %% [markdown]
# # F3.2d — DG_TRIP_COUNT TRAIN fitting
# Orchestration/inspection only. Official execution is performed by `python -m simfleet_edg.repro.f3_2d_fit_trip_count` after the implementation commit is frozen. CAL and TEST are not opened here.
