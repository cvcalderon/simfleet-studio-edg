# %% [markdown]
# # R0 — Environment inspection
# Scientific inspection notebook. The official R0 run is executed from the Python module/CLI; this notebook contains no authoritative R0 logic.

# %%
from pathlib import Path

from simfleet_edg.common.environment import collect_environment

cwd = Path.cwd().resolve()
PROJECT_ROOT = cwd.parent if cwd.name == 'notebooks' else cwd
PROJECT_ROOT

# %%
env = collect_environment(PROJECT_ROOT)
{
    'python': env['python'],
    'system': env['system'],
    'hardware': env['hardware'],
    'git': env['git'],
}

# %% [markdown]
# ## Official execution
# After C-IMPL-02 is committed and pushed, run R0 from a clean `main` using:
#
# `python -m simfleet_edg.repro.r0_environment --config configs/reproduction/r0_environment.yaml --out artifacts/runs/R0_environment_v1`
