# %% [markdown]
# # R1 source audit inspection
# This notebook does not implement R1. It inspects the RunBundle generated by `src/simfleet_edg/repro/r1_source_audit.py`.

# %%
from pathlib import Path

import pandas as pd

ROOT = Path.cwd().resolve()
if ROOT.name == 'notebooks':
    ROOT = ROOT.parent
RUN = ROOT / 'artifacts' / 'runs' / 'R1_source_audit_v1'
RUN

# %%
audit = pd.read_csv(RUN / 'source_audit.csv')
validation = pd.read_csv(RUN / 'r1_validation.csv')
display(validation)
display(audit[['source_id','required','exists','hash_match','structure_status','status']])
