# %% [markdown]
# # R5 — D_REPLAY reproduction
# Thin scientific interface. Core implementation lives in `simfleet_edg.common.demand_replay` and `simfleet_edg.repro.r5_d_replay`.

# %%
from pathlib import Path

import yaml

cfg = yaml.safe_load(Path('../configs/reproduction/r5_d_replay.yaml').read_text())
cfg['replay']
